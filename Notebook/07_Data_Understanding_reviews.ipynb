# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
reviews = pd.read_csv("D:\\E-Commerce-Project\\dataset\\reviews.csv")

# %%
reviews.head(5)
# Out:
#                               review_id                               user_id  \
# 0  e4ad6f1e-6449-4793-a131-17192b03e509  f6cadab8-2be9-4480-a278-71846245a809
# 1  0c5734c1-dacb-4028-a50a-507ca9c92aeb  d89694d2-292d-42d4-b090-947c1e292c98
# 2  d978ff74-a828-4f62-b550-f70664aca6aa  4f92de48-e30b-49e8-9584-8868945497d0
# 3  50332ba8-4577-439d-8111-ef0b5960acd5  845e33f0-1aab-4df5-9a49-0a50fd5a4298
# 4  8bdb7c01-41cf-44cb-99c9-8862c5d833b0  0da6cc24-2cd4-42dc-88e8-137951cd5ef5
#
#                              product_id purchase_id  rating  \
# 0  99aee34b-3b16-4337-8132-f183349dfd69         NaN       4
# 1  38685bcb-3aef-4d81-abeb-101f9beee4fd         NaN       5
# 2  aba49dc2-3182-4614-a4ad-e2b537d50b04         NaN       4
# 3  d30b76ee-5a18-4e36-bbb7-84723460be23         NaN       3
# 4  61113e39-9a12-48a9-840b-dd7368dca11c         NaN       3
#
#                                                title  \
# 0                                A reliable purchase
# 1  This Studio: A Comprehensive Guide is a game c...
# 2  Very satisfied with this Cuisinart Non-Stick K...
# 3                       Not bad but not great either
# 4                                 Function over form
#
#                                          review_text  \
# 0  This Staples Organization Set does exactly wha...
# 1  I did not expect to love this as much as I do....
# 2  This Cuisinart Non-Stick Kitchenware has held ...
# 3  This Fitness for Professionals gets the job do...
# 4  This MSR Performance Cycling works fine but th...
#
#                      review_date
# 0  2022-01-13 00:00:00.000000000
# 1  2022-01-15 00:00:00.000000000
# 2  2022-01-26 00:00:00.000000000
# 3  2022-02-02 00:00:00.000000000
# 4  2022-02-08 00:00:00.000000000

# %%
reviews.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   review_id    1253 non-null   str
#  1   user_id      1253 non-null   str
#  2   product_id   1253 non-null   str
#  3   purchase_id  1053 non-null   str
#  4   rating       1253 non-null   int64
#  5   title        1253 non-null   str
#  6   review_text  1253 non-null   str
#  7   review_date  1253 non-null   str
# dtypes: int64(1), str(7)
# memory usage: 1.4 MB

# %%
reviews.isnull().sum()
# Out:
# review_id        0
# user_id          0
# product_id       0
# purchase_id    200
# rating           0
# title            0
# review_text      0
# review_date      0
# dtype: int64

# %%
reviews['review_date'] = pd.to_datetime(reviews['review_date'])

# %%
reviews.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   review_id    1253 non-null   str
#  1   user_id      1253 non-null   str
#  2   product_id   1253 non-null   str
#  3   purchase_id  1053 non-null   str
#  4   rating       1253 non-null   int64
#  5   title        1253 non-null   str
#  6   review_text  1253 non-null   str
#  7   review_date  1253 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), str(6)
# memory usage: 1.4 MB

# %%
reviews.duplicated().sum()
# Out:
# np.int64(0)

# %%
reviews['purchase_id'] = reviews['purchase_id'].fillna("UNKNOWN")

# %%
reviews.isnull().sum()
# Out:
# review_id      0
# user_id        0
# product_id     0
# purchase_id    0
# rating         0
# title          0
# review_text    0
# review_date    0
# dtype: int64

# %%
reviews['rating'].value_counts()
# Out:
# rating
# 5    645
# 4    286
# 3    150
# 2    108
# 1     64
# Name: count, dtype: int64

# %%
reviews['title'].value_counts()
# Out:
# title
# Outstanding quality and performance                   54
# I am blown away by the quality                        50
# Exceeded all my expectations                          48
# Five stars all the way                                47
# Absolutely phenomenal product                         47
#                                                       ..
# Very satisfied with this Dyson Modern Home Decor       1
# Absolutely love this Canon Stationery!                 1
# Top notch quality from Tommy Hilfiger                  1
# Pleasantly surprised by Apple Accessorie Stand         1
# Perfect Bosch Prime6 Electronic — highly recommend     1
# Name: count, Length: 303, dtype: int64

# %%
plt.figure(figsize=(8,5))

plt.hist(
    reviews["rating"],
    bins=20,
    edgecolor="black"
)

plt.title("Rating Count Distribution")

plt.xlabel("Reviews")

plt.ylabel("Count")

plt.grid()

plt.show()

# %%
reviews.to_csv(
    "cleaned_data/reviews_cleaned.csv",
    index=False
)
